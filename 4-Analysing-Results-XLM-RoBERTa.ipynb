# %%
import json
import pandas as pd
import numpy as np
from sklearn.metrics import f1_score,confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import the files

# %%
# Import the file with results:

# results of experiments with XLM-RoBERTa
with open("results-RoBERTa/main-classification-results-roberta-3runs.json") as results_file:
    results = json.load(results_file)

# results of experiments with CroSloEngual BERT:
#with open("results-CroSloEngualBERT/main-classification-results-crosloengualbert3runs.json") as results_file:
#    results = json.load(results_file)

# %%
# Import one training file to get the labels.
train_df = pd.read_csv("G:\My Drive\GitHub\Cross-Lingual-and-Cross-Dataset-Experiments-with-Genre-Datasets\data\SI_GINCO_train.csv")
train_df.head()
# Out:
#                                                 text                 labels
# 0  PES - BITJE ZA OSAMLJENE? <p/> Življenje z živ...  Opinion/Argumentation
# 1  Predelne stene <p/> Pogosto se zgodi da pri gr...              Promotion
# 2  V Izoli se je končal 9. mednarodni turnir v go...                   News
# 3  Okvirji za vaše plakate <p/> Pri naročilu okvi...            Instruction
# 4  Bojijo se lakote <p/> Sto ekip, 30 evropskih m...                   News

# %%
LABELS = list(train_df.labels.unique())
LABELS
# Out:
# ['Opinion/Argumentation',
#  'Promotion',
#  'News',
#  'Instruction',
#  'Information/Explanation',
#  'Legal/Regulation',
#  'Review',
#  'Research Article',
#  'Forum',
#  'Recipe',
#  'Prose',
#  'Interview']

# %%
# Calculate scores per labels and add this information to results
for instance in results:
    y_true = instance["y_true"]
    y_pred = instance["y_pred"]

    score_per_label = list(f1_score(y_true, y_pred, labels=LABELS, average=None))

    dict_score_per_label = {}

    for index in range(len(LABELS)):
        dict_score_per_label[LABELS[index]] = score_per_label[index]

    instance["scores_per_labels"] = dict_score_per_label

# %%
# Add to the results one column where trained_on and tested_on are joined
for instance in results:
    current_trained_on = instance["trained_on"]
    current_tested_on = instance["tested_on"]
    current_setup = f"{current_trained_on},{current_tested_on}"
    instance["setup"] = current_setup

# %%
# Inspect the results as a dataframe
results_df = pd.DataFrame(results)
results_df.head()
# Out:
#   trained_on tested_on   microF1   macroF1  \
# 0   SL-GINCO  SL-GINCO  0.802469  0.734463
# 1   SL-GINCO      CORE  0.631191  0.536556
# 2   MT-GINCO  MT-GINCO  0.814815  0.869582
# 3   MT-GINCO      CORE  0.634434  0.536819
# 4       CORE      CORE  0.768573  0.719598
#
#                                               y_true  \
# 0  [Promotion, News, Promotion, News, Instruction...
# 1  [News, News, News, News, Information/Explanati...
# 2  [Promotion, News, Promotion, News, Instruction...
# 3  [News, News, News, News, Information/Explanati...
# 4  [News, News, News, News, Information/Explanati...
#
#                                               y_pred  \
# 0  [Promotion, News, Promotion, News, Promotion, ...
# 1  [News, Promotion, News, News, Opinion/Argument...
# 2  [Promotion, News, Promotion, News, Instruction...
# 3  [News, News, News, News, Opinion/Argumentation...
# 4  [News, News, News, News, Information/Explanati...
#
#                                    scores_per_labels              setup
# 0  {'Opinion/Argumentation': 0.5789473684210527, ...  SL-GINCO,SL-GINCO
# 1  {'Opinion/Argumentation': 0.5864618885096701, ...      SL-GINCO,CORE
# 2  {'Opinion/Argumentation': 0.6341463414634148, ...  MT-GINCO,MT-GINCO
# 3  {'Opinion/Argumentation': 0.5953194846174072, ...      MT-GINCO,CORE
# 4  {'Opinion/Argumentation': 0.7313389485913447, ...          CORE,CORE

# %%
results_df.describe()
# Out:
#          microF1    macroF1
# count  21.000000  21.000000
# mean    0.693121   0.654249
# std     0.084457   0.112165
# min     0.580247   0.504322
# 25%     0.629630   0.544445
# 50%     0.651386   0.668220
# 75%     0.768721   0.719598
# max     0.814815   0.869582

# %%
setups = list(results_df.setup.unique())
print(setups)
# Out:
# ['SL-GINCO,SL-GINCO', 'SL-GINCO,CORE', 'MT-GINCO,MT-GINCO', 'MT-GINCO,CORE', 'CORE,CORE', 'CORE,SL-GINCO', 'CORE,MT-GINCO']

# %%
# Create a dictionary of results, averaged over all the runs. In the dictionary, setups are keys and its values are dictionaries that contain average micro f1, micro f1 std, average macro f1, macro f1 std, average f1s per labels and std for results for labels.
average_results = {}

for setup in setups:
    # Add new key if it is not yet in the dictionary
    if setup not in average_results:
        average_results[setup] = {"microF1": 0, "micro_std": 0, "macroF1": 0, "macro_std": 0, "labels_f1": [], "labels_std": []}
    
    average_label_score = {'Opinion/Argumentation': [], 'Promotion': [], 'News': [], 'Instruction': [], 'Information/Explanation': [], 'Legal/Regulation': [], 'Review': [], 'Research Article': [], 'Forum': [], 'Recipe': [], 'Prose': [], 'Interview': []}

    average_micro = []
    average_macro = []

    for element in results:
        if element["setup"] == setup:
            # Add micro and macro scores to the list of micro and macro scores for this setup
            average_micro.append(element["microF1"])
            average_macro.append(element["macroF1"])
            # Add label scores to the dictionary of setup label scores
            for key in list(average_label_score.keys()):
                average_label_score[key].append(element["scores_per_labels"][key])

    # Calculate average micros and macros and std based on the lists of all scores
    average_results[setup]["microF1"] = np.array(average_micro).mean()
    average_results[setup]["micro_std"] = np.array(average_micro).std()
    average_results[setup]["macroF1"] = np.array(average_macro).mean()
    average_results[setup]["macro_std"] = np.array(average_macro).std()
    average_results[setup]["label_scores"] = average_label_score

    # Calculate average scores for each label based on the average_label_score list
    #average_results[setup]["labels_f1"] = [np.array(average_label_score[key]).mean() for key in list(average_label_score.keys())]
    #average_results[setup]["labels_std"] = [np.array(average_label_score[key]).std() for key in list(average_label_score.keys())]

    average_results[setup]["labels_f1"] = {'Opinion/Argumentation': [], 'Promotion': [], 'News': [], 'Instruction': [], 'Information/Explanation': [], 'Legal/Regulation': [], 'Review': [], 'Research Article': [], 'Forum': [], 'Recipe': [], 'Prose': [], 'Interview': []}
    for key in list(average_results[setup]["labels_f1"].keys()):
        average_results[setup]["labels_f1"][key] = np.array(average_label_score[key]).mean()
    average_results[setup]["labels_std"] = {'Opinion/Argumentation': [], 'Promotion': [], 'News': [], 'Instruction': [], 'Information/Explanation': [], 'Legal/Regulation': [], 'Review': [], 'Research Article': [], 'Forum': [], 'Recipe': [], 'Prose': [], 'Interview': []}
    for key in list(average_results[setup]["labels_std"].keys()):
        average_results[setup]["labels_std"][key] = np.array(average_label_score[key]).std()

# %%
print(average_results["SL-GINCO,SL-GINCO"])
# Out:
# {'microF1': 0.7818930041152262, 'micro_std': 0.017700257751116503, 'macroF1': 0.7251996974888658, 'macro_std': 0.010282594277491109, 'labels_f1': {'Opinion/Argumentation': 0.5861448493027441, 'Promotion': 0.849591419816139, 'News': 0.8216775146563265, 'Instruction': 0.8772875816993464, 'Information/Explanation': 0.7266322024594664, 'Legal/Regulation': 0.5555555555555555, 'Review': 0.3, 'Research Article': 1.0, 'Forum': 0.9855072463768115, 'Recipe': 1.0, 'Prose': 0.0, 'Interview': 1.0}, 'labels_std': {'Opinion/Argumentation': 0.06301329257437326, 'Promotion': 0.01934810706564666, 'News': 0.022678109675622785, 'Instruction': 0.04485643818885391, 'Information/Explanation': 0.035856127242372395, 'Legal/Regulation': 0.15713484026367722, 'Review': 0.1414213562373095, 'Research Article': 0.0, 'Forum': 0.02049584873004484, 'Recipe': 0.0, 'Prose': 0.0, 'Interview': 0.0}, 'label_scores': {'Opinion/Argumentation': [0.5789473684210527, 0.6666666666666667, 0.5128205128205129], 'Promotion': [0.8764044943820225, 0.8314606741573034, 0.8409090909090908], 'News': [0.8505747126436782, 0.8192771084337348, 0.7951807228915663], 'Instruction': [0.875, 0.9333333333333333, 0.823529411764706], 'Information/Explanation': [0.7659574468085107, 0.6792452830188679, 0.7346938775510203], 'Legal/Regulation': [0.6666666666666666, 0.3333333333333333, 0.6666666666666666], 'Review': [0.2, 0.5, 0.2], 'Research Article': [1.0, 1.0, 1.0], 'Forum': [1.0, 1.0, 0.9565217391304348], 'Recipe': [1.0, 1.0, 1.0], 'Prose': [0.0, 0.0, 0.0], 'Interview': [1.0, 1.0, 1.0]}}

# %% [markdown]
# ## Print Latex Tables

# %%
# Print out a latex table with average micro and macro scores and stds
# Get a Latex table with mean and std results

print("\\hline")
print("\\textbf{Setup (Trained on, Tested on)} & \\textbf{Micro F1} & \\textbf{Macro F1}\\\\")
print("\\hline\\hline")

for element in list(average_results.keys()):
    print(f"{element} & {round(average_results[element]['microF1'],3)} $\pm$ {round(average_results[element]['micro_std'],2)} & {round(average_results[element]['macroF1'],3)} $\pm$ {round(average_results[element]['macro_std'],2)} \\\\")
# Out:
# \hline
# \textbf{Setup (Trained on, Tested on)} & \textbf{Micro F1} & \textbf{Macro F1}\\
# \hline\hline
# SL-GINCO,SL-GINCO & 0.782 $\pm$ 0.02 & 0.725 $\pm$ 0.01 \\
# SL-GINCO,CORE & 0.639 $\pm$ 0.01 & 0.539 $\pm$ 0.01 \\
# MT-GINCO,MT-GINCO & 0.807 $\pm$ 0.01 & 0.841 $\pm$ 0.03 \\
# MT-GINCO,CORE & 0.625 $\pm$ 0.01 & 0.521 $\pm$ 0.01 \\
# CORE,CORE & 0.768 $\pm$ 0.0 & 0.715 $\pm$ 0.0 \\
# CORE,SL-GINCO & 0.603 $\pm$ 0.02 & 0.575 $\pm$ 0.03 \\
# CORE,MT-GINCO & 0.63 $\pm$ 0.02 & 0.663 $\pm$ 0.03 \\

# %% [markdown]
# ## Print Markdown Tables

# %%
print("|Setup (Trained on, Tested on)|Micro F1|Macro F1|")
print("|:----|----|----:|")

for element in list(average_results.keys()):
    print(f"|{element} | {round(average_results[element]['microF1'],3)} +/- {round(average_results[element]['micro_std'],2)} | {round(average_results[element]['macroF1'],3)} +/- {round(average_results[element]['macro_std'],2)} |")
# Out:
# |Setup (Trained on, Tested on)|Micro F1|Macro F1|
# |:----|----|----:|
# |SL-GINCO,SL-GINCO | 0.782 +/- 0.02 | 0.725 +/- 0.01 |
# |SL-GINCO,CORE | 0.639 +/- 0.01 | 0.539 +/- 0.01 |
# |MT-GINCO,MT-GINCO | 0.807 +/- 0.01 | 0.841 +/- 0.03 |
# |MT-GINCO,CORE | 0.625 +/- 0.01 | 0.521 +/- 0.01 |
# |CORE,CORE | 0.768 +/- 0.0 | 0.715 +/- 0.0 |
# |CORE,SL-GINCO | 0.603 +/- 0.02 | 0.575 +/- 0.03 |
# |CORE,MT-GINCO | 0.63 +/- 0.02 | 0.663 +/- 0.03 |

# %% [markdown]
# |Setup (Trained on, Tested on)|Micro F1|Macro F1|
# |:----|----|----:|
# |SL-GINCO,SL-GINCO | 0.793 +/- 0.01 | 0.732 +/- 0.0 |
# |MT-GINCO,MT-GINCO | 0.815 +/- 0.0 | 0.859 +/- 0.01 |
# |CORE,CORE | 0.767 +/- 0.0 | 0.716 +/- 0.0 |
# |CORE,SL-GINCO | 0.59 +/- 0.01 | 0.59 +/- 0.02 |
# |CORE,MT-GINCO | 0.617 +/- 0.01 | 0.647 +/- 0.02 |
# |SL-GINCO,CORE | 0.641 +/- 0.01 | 0.546 +/- 0.01 |
# |MT-GINCO,CORE | 0.628 +/- 0.01 | 0.529 +/- 0.01 |

# %% [markdown]
# ## Plot: Macro and micro F1 scores

# %% [markdown]
# ### All setups

# %%
# Plot the differences between the average micro and macro scores for different setups:
average_mi = []
average_mi_std = []
average_ma = []
average_ma_std = []

for setup in setups:
    current_i = setup
    average_mi.append(average_results[current_i]["microF1"])
    average_mi_std.append(average_results[current_i]["micro_std"])
    average_ma.append(average_results[current_i]["macroF1"])
    average_ma_std.append(average_results[current_i]["macro_std"])

fig, ax = plt.subplots(figsize=(4,4), dpi=100)

ax.errorbar(setups, average_mi, yerr=average_mi_std, fmt='-o', label="Micro F1", capsize=3)
ax.errorbar(setups, average_ma, yerr=average_ma_std, fmt='-o', label="Macro F1", capsize=3)

plt.xticks(fontsize=6)
ax.set_xlabel('Setups')
ax.set_ylabel('F1 Scores')
xlabels = setups
ax.set_xticklabels(xlabels, rotation=45, ha='right')
ax.legend(loc="lower right")
ax.set_xlabel("Average micro and macro F1\nscores for all setups")
fig.tight_layout()
#plt.savefig("results-RoBERTa\RoBERTa-scores-per-setups.png")
plt.show()
# Out:
# C:\Users\TajaK\AppData\Local\Temp\ipykernel_18380\1089293442.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xlabels, rotation=45, ha='right')

# %% [markdown]
# ### In-dataset experiments

# %%
# Plot the figure for in-dataset experiments
# Plot the differences between the average micro and macro scores for different setups:
setup_of_interest = ['SL-GINCO,SL-GINCO', 'MT-GINCO,MT-GINCO', 'CORE,CORE' ]

average_mi = []
average_mi_std = []
average_ma = []
average_ma_std = []

for setup in setup_of_interest:
    current_i = setup
    average_mi.append(average_results[current_i]["microF1"])
    average_mi_std.append(average_results[current_i]["micro_std"])
    average_ma.append(average_results[current_i]["macroF1"])
    average_ma_std.append(average_results[current_i]["macro_std"])

fig, ax = plt.subplots(figsize=(4,4), dpi=400)

ax.errorbar(setup_of_interest, average_mi, yerr=average_mi_std, fmt='-o', label="Micro F1", capsize=3)
ax.errorbar(setup_of_interest, average_ma, yerr=average_ma_std, fmt='-o', label="Macro F1", capsize=3)

plt.xticks(fontsize=6)
ax.set_xlabel('Setups')
ax.set_ylabel('F1 Scores')
xlabels = setup_of_interest
ax.set_xticklabels(xlabels, rotation=45, ha='right')
ax.legend(loc="lower right")
ax.set_xlabel("Average micro and macro F1\nscores for in-dataset setups")
fig.tight_layout()
#plt.savefig("results-RoBERTa\RoBERTa-scores-SI-GINCO-indataset-vs-transfer-to-CORE.png")
plt.show()
# Out:
# C:\Users\TajaK\AppData\Local\Temp\ipykernel_18380\890438554.py:26: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xlabels, rotation=45, ha='right')

# %% [markdown]
# ### Cross-lingual experiments

# %%
# Plot the figure for cross-lingual experiments
# Plot the differences between the average micro and macro scores for different setups:
setup_of_interest = ['SL-GINCO,CORE', 'MT-GINCO,CORE','CORE,SL-GINCO']

average_mi = []
average_mi_std = []
average_ma = []
average_ma_std = []

for setup in setup_of_interest:
    current_i = setup
    average_mi.append(average_results[current_i]["microF1"])
    average_mi_std.append(average_results[current_i]["micro_std"])
    average_ma.append(average_results[current_i]["macroF1"])
    average_ma_std.append(average_results[current_i]["macro_std"])

fig, ax = plt.subplots(figsize=(4,4), dpi=200)

ax.errorbar(setup_of_interest, average_mi, yerr=average_mi_std, fmt='-o', label="Micro F1", capsize=3)
ax.errorbar(setup_of_interest, average_ma, yerr=average_ma_std, fmt='-o', label="Macro F1", capsize=3)

plt.xticks(fontsize=6)
ax.set_xlabel('Setups')
ax.set_ylabel('F1 Scores')
xlabels = setup_of_interest
ax.set_xticklabels(xlabels, rotation=45, ha='right')
ax.legend(loc="lower right")
ax.set_xlabel("Average micro and macro F1 scores for cross-lingual setups")
fig.tight_layout()
#plt.savefig("results-RoBERTa\label-scores-SI-GINCO-indataset-vs-transfer-to-CORE.png")
plt.show()
# Out:
# C:\Users\TajaK\AppData\Local\Temp\ipykernel_18380\1640720754.py:26: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xlabels, rotation=45, ha='right')

# %% [markdown]
# ## Plot: Scores per Labels

# %%
#List of label's names based on their frequency in the GINCO corpus:
labels_frequency_list = ["Promotion","News","Information/Explanation","Opinion/Argumentation","Forum","Instruction","Review","Legal/Regulation","Research Article","Interview","Recipe","Prose"]

fig, ax = plt.subplots(figsize=(4,4), dpi=400)
for setup in setups:
    current_i = setup
    current_i_list = current_i.split(",")
    trained_on = current_i_list[0]
    tested_on = current_i_list[1]
    if trained_on in ["CORE"] and tested_on in ["CORE"]:
        plot_label = "Trained on EN-GINCORE, tested on EN-GINCORE"
        x_SL_in_XLM = []
        for label in labels_frequency_list:
            x_SL_in_XLM.append(average_results[current_i]['labels_f1'][label])
        yerr_SL_in_XLM = []
        for label in labels_frequency_list:
            yerr_SL_in_XLM.append(average_results[current_i]["labels_std"][label])
        ax.errorbar(labels_frequency_list, x_SL_in_XLM, yerr_SL_in_XLM, color="darkolivegreen", fmt='-o', label=plot_label, capsize=3)
    elif trained_on in ["CORE"] and tested_on in ["SL-GINCO"]:
        plot_label = f"Trained on EN-GINCORE, tested on SL-GINCORE"
        x_CORE_XLM = []
        for label in labels_frequency_list:
            x_CORE_XLM.append(average_results[current_i]['labels_f1'][label])
        yerr_CORE_XLM = []
        for label in labels_frequency_list:
            yerr_CORE_XLM.append(average_results[current_i]["labels_std"][label])
        ax.errorbar(labels_frequency_list, x_CORE_XLM, yerr_CORE_XLM, color= "cornflowerblue", fmt='-o', label=plot_label, capsize=3)

plt.xticks(fontsize=6)
ax.set_xlabel('Labels')
ax.set_ylabel('F1 Scores')
xlabels = labels_frequency_list
ax.set_xticklabels(xlabels, rotation=45, ha='right')
ax.legend(loc="lower left", prop={'size': 8})
#ax.set_xlabel("Difference between labels scores between EN-GINCORE and MT-GINCORE \n(in-dataset experiments with XLM-RoBERTa)")
fig.tight_layout()
#plt.savefig("results-RoBERTa\label-scores-indataset-CORE-MT-GINCO-XLMRoBERTa.png")
plt.show()
# Out:
# C:\Users\TajaK\AppData\Local\Temp\ipykernel_18380\2310036424.py:33: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xlabels, rotation=45, ha='right')

# %%
# Join comparison of XLM-RoBERTa and CroSloEngualBERT
x_SL_CSE = [0.8090398365679264, 0.7965551302629954, 0.5940982776089159, 0.6462668298653611, 0.9272256728778469, 0.7042483660130718, 0.0, 0.375, 0.8333333333333333, 0.75, 0.75, 0.0]
yerr_SL_CSE = [0.01714112874058112, 0.011068129785048668, 0.039279479456415425, 0.03396434987885337, 0.027265005556841682, 0.045370729989917695, 0.0, 0.21650635094610965, 0.16666666666666669, 0.4330127018922193, 0.4330127018922193, 0.0]
x_CORE_CSE = [0.3191883246100726, 0.7124580930587778, 0.3499582211613528, 0.5560789016045916, 0.34836778324851725, 0.37997054153839555, 0.4027797499357584, 0.46537338339591167, 0.47556310363165394, 0.1862885309558118, 0.05882352941176471, 0.43804565029383724]
yerr_CORE_CSE = [0.009268451302862267, 0.013273371185560712, 0.02935124624330425, 0.017227591953430387, 0.08334553617480622, 0.017342311377920024, 0.030264565066782885, 0.030624281598028758, 0.012396070924377549, 0.07701862136316429, 0.0, 0.041301093308675055]

fig, ax = plt.subplots(figsize=(4,4), dpi=400)
ax.errorbar(labels_frequency_list, x_SL_in_XLM, yerr_SL_in_XLM, color="crimson", fmt='-o', label="SL-GINCORE (in-dataset)", capsize=3)
#ax.errorbar(labels_frequency_list, x_SL_CSE, yerr_SL_CSE, color= "orchid", fmt='-o', label="SL-GINCO (in-dataset), CSEBERT", capsize=3)
ax.errorbar(labels_frequency_list, x_CORE_XLM, yerr_CORE_XLM, color = "orchid", fmt='-o', label="Transfer from SL-GINCORE to EN-GINCORE", capsize=3)
#ax.errorbar(labels_frequency_list, x_CORE_CSE, yerr_CORE_CSE, color = "teal", fmt='-o', label="Transfer from SL-GINCORE to EN-GINCORE, CSEBERT", capsize=3)

plt.xticks(fontsize=6)
ax.set_xlabel('Labels')
ax.set_ylabel('F1 Scores')
xlabels = labels_frequency_list
ax.set_xticklabels(xlabels, rotation=45, ha='right')
ax.legend(loc="lower left", prop={'size': 5})
ax.set_xlabel("Difference between labels scores between in-dataset experiments\n and cross-dataset experiments with XLM-RoBERTa")
fig.tight_layout()
plt.savefig("results-RoBERTa\label-scores-indataset-vs-crossdataset-XLM-RoBERTa.png")
plt.show()
# Out:
# C:\Users\TajaK\AppData\Local\Temp\ipykernel_17808\1258004252.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xlabels, rotation=45, ha='right')

# %% [markdown]
# ## Plot: Confusion Matrix

# %%
# See which setups you can choose
results_df
# Out:
#    trained_on tested_on   microF1   macroF1  \
# 0    SL-GINCO  SL-GINCO  0.722222  0.503678
# 1    SL-GINCO      CORE  0.558225  0.416810
# 2    MT-GINCO  MT-GINCO  0.716049  0.535164
# 3    MT-GINCO      CORE  0.597288  0.419149
# 4        CORE  SL-GINCO  0.543210  0.477446
# 5        CORE  MT-GINCO  0.635802  0.553304
# 6        CORE      CORE  0.759434  0.703473
# 7    SL-GINCO  SL-GINCO  0.746914  0.664956
# 8    SL-GINCO      CORE  0.558078  0.396488
# 9    MT-GINCO  MT-GINCO  0.716049  0.536818
# 10   MT-GINCO      CORE  0.575619  0.405734
# 11       CORE  SL-GINCO  0.586420  0.498048
# 12       CORE  MT-GINCO  0.635802  0.541210
# 13       CORE      CORE  0.764446  0.709241
# 14   SL-GINCO  SL-GINCO  0.746914  0.647552
# 15   SL-GINCO  SL-GINCO  0.734568  0.579069
# 16   SL-GINCO      CORE  0.524469  0.359926
# 17   MT-GINCO  MT-GINCO  0.709877  0.430366
# 18   MT-GINCO      CORE  0.583579  0.401621
# 19       CORE  SL-GINCO  0.567901  0.555880
# 20       CORE  MT-GINCO  0.617284  0.535149
# 21       CORE      CORE  0.759729  0.704858
#
#                                                y_true  \
# 0   [Promotion, News, Promotion, News, Instruction...
# 1   [News, News, News, News, Information/Explanati...
# 2   [Promotion, News, Promotion, News, Instruction...
# 3   [News, News, News, News, Information/Explanati...
# 4   [Promotion, News, Promotion, News, Instruction...
# 5   [Promotion, News, Promotion, News, Instruction...
# 6   [News, News, News, News, Information/Explanati...
# 7   [Promotion, News, Promotion, News, Instruction...
# 8   [News, News, News, News, Information/Explanati...
# 9   [Promotion, News, Promotion, News, Instruction...
# 10  [News, News, News, News, Information/Explanati...
# 11  [Promotion, News, Promotion, News, Instruction...
# 12  [Promotion, News, Promotion, News, Instruction...
# 13  [News, News, News, News, Information/Explanati...
# 14  [Promotion, News, Promotion, News, Instruction...
# 15  [Promotion, News, Promotion, News, Instruction...
# 16  [News, News, News, News, Information/Explanati...
# 17  [Promotion, News, Promotion, News, Instruction...
# 18  [News, News, News, News, Information/Explanati...
# 19  [Promotion, News, Promotion, News, Instruction...
# 20  [Promotion, News, Promotion, News, Instruction...
# 21  [News, News, News, News, Information/Explanati...
#
#                                                y_pred  \
# 0   [Promotion, News, Promotion, News, Instruction...
# 1   [News, Opinion/Argumentation, News, Opinion/Ar...
# 2   [Promotion, News, Promotion, News, Instruction...
# 3   [News, Promotion, News, News, Opinion/Argument...
# 4   [Promotion, News, Information/Explanation, New...
# 5   [Promotion, News, Information/Explanation, New...
# 6   [News, News, News, News, Opinion/Argumentation...
# 7   [Promotion, News, Promotion, News, Promotion, ...
# 8   [News, Promotion, News, News, Opinion/Argument...
# 9   [Promotion, News, Information/Explanation, New...
# 10  [News, Promotion, News, News, Opinion/Argument...
# 11  [Promotion, News, Information/Explanation, New...
# 12  [Promotion, News, Information/Explanation, New...
# 13  [News, News, News, News, Information/Explanati...
# 14  [Promotion, News, Promotion, News, Instruction...
# 15  [Promotion, News, Promotion, News, Promotion, ...
# 16  [News, Promotion, News, Opinion/Argumentation,...
# 17  [Promotion, News, Information/Explanation, New...
# 18  [News, Promotion, News, News, News, Opinion/Ar...
# 19  [Promotion, News, Information/Explanation, New...
# 20  [Promotion, News, Information/Explanation, New...
# 21  [News, News, News, News, Information/Explanati...
#
#                                     scores_per_labels              setup
# 0   {'Opinion/Argumentation': 0.6511627906976744, ...  SL-GINCO,SL-GINCO
# 1   {'Opinion/Argumentation': 0.5649274225186347, ...      SL-GINCO,CORE
# 2   {'Opinion/Argumentation': 0.5, 'Promotion': 0....  MT-GINCO,MT-GINCO
# 3   {'Opinion/Argumentation': 0.5732170802593338, ...      MT-GINCO,CORE
# 4   {'Opinion/Argumentation': 0.35714285714285715,...      CORE,SL-GINCO
# 5   {'Opinion/Argumentation': 0.5294117647058824, ...      CORE,MT-GINCO
# 6   {'Opinion/Argumentation': 0.7211728221031858, ...          CORE,CORE
# 7   {'Opinion/Argumentation': 0.631578947368421, '...  SL-GINCO,SL-GINCO
# 8   {'Opinion/Argumentation': 0.5713132943312488, ...      SL-GINCO,CORE
# 9   {'Opinion/Argumentation': 0.6222222222222223, ...  MT-GINCO,MT-GINCO
# 10  {'Opinion/Argumentation': 0.5358507529781974, ...      MT-GINCO,CORE
# 11  {'Opinion/Argumentation': 0.5405405405405405, ...      CORE,SL-GINCO
# 12  {'Opinion/Argumentation': 0.5882352941176471, ...      CORE,MT-GINCO
# 13  {'Opinion/Argumentation': 0.7336683417085428, ...          CORE,CORE
# 14  {'Opinion/Argumentation': 0.6976744186046512, ...  SL-GINCO,SL-GINCO
# 15  {'Opinion/Argumentation': 0.6046511627906977, ...  SL-GINCO,SL-GINCO
# 16  {'Opinion/Argumentation': 0.5319959879638916, ...      SL-GINCO,CORE
# 17  {'Opinion/Argumentation': 0.6363636363636364, ...  MT-GINCO,MT-GINCO
# 18  {'Opinion/Argumentation': 0.5293961159882947, ...      MT-GINCO,CORE
# 19  {'Opinion/Argumentation': 0.5555555555555556, ...      CORE,SL-GINCO
# 20  {'Opinion/Argumentation': 0.5454545454545455, ...      CORE,MT-GINCO
# 21  {'Opinion/Argumentation': 0.7268610246249646, ...          CORE,CORE

# %%
# Plot the confusion matrix:
# Choose the setup (take the index from the results_df table) 
setup = results[11]
trained_on = setup["trained_on"]
tested_on = setup["tested_on"]

y_true = setup["y_true"]
y_pred = setup["y_pred"]

# To display normalized values, leave normalize = "true", otherwise delete that
disp = ConfusionMatrixDisplay.from_predictions(y_true, y_pred, labels = LABELS, normalize = "true", xticks_rotation=90, cmap='plasma', colorbar=True, values_format=".1g")
#disp = ConfusionMatrixDisplay.from_predictions(y_true, y_pred, labels = LABELS, xticks_rotation=90, cmap='plasma', colorbar=True, values_format=".1g")

fig, ax = plt.subplots(figsize=(10,10))
disp.plot(ax=ax)
plt.xticks(np.arange(len(LABELS)), LABELS, rotation=90)
plt.title(f"Trained on {trained_on}, tested on {tested_on}")
plt.tight_layout()
fig1 = plt.gcf()
fig1.savefig(f"results-CroSloEngualBERT/Normalized confusion-matrix-{trained_on}-test-on-{tested_on}.png",dpi=100)
