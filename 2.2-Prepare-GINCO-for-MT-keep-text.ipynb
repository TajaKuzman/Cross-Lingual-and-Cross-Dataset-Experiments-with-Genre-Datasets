# %% [markdown]
# In this notebook, I will prepare the GINCO corpus for machine translation. To be able to use as much useful text as possible, we will use all paragraphs, marked as "keep". The paragraphs will be joint into full text (attribute "full_text").
#
# Although we won't use all labels in the experiments, I will machine translate all texts so that they could be used in any other experiments.

# %%
# Import the GINCO dataset
import json

with open("data/GINCO-mapped-to-GINCORE.json", "r") as file:
    dataset = json.load(file)

# %%
dataset[0]
# Out:
# {'id': '3949',
#  'url': 'http://www.pomurje.si/aktualno/sport/zimska-liga-malega-nogometa/',
#  'crawled': '2014',
#  'hard': False,
#  'paragraphs': [{'text': 'Šport', 'duplicate': False, 'keep': True},
#   {'text': 'Zimska liga malega nogometa sobota, 12.02.2011',
#    'duplicate': False,
#    'keep': True},
#   {'text': 'avtor: Tonček Gider', 'duplicate': False, 'keep': True},
#   {'text': "V 7. krogu zimske lige v malem nogometu v Križevcih pri Ljutomeru je v prvi ligi vodilni 100 plus iz Križevec izgubil s tretjo ekipo na lestvici Rock'n roll iz Križevec z rezultatom 1:2, druga na lestvici Top Finedika iz Križevec je bila poražena z ekipo Bar Milene iz Ključarovec z rezultatom 7:8. V drugi križevski ligi je vodilni Cafe del Mar iz Vučje vasi premagal Montažo Vrbnjak iz Stare Nove vasi z rezultatom 3:2.",
#    'duplicate': False,
#    'keep': True},
#   {'text': 'oglasno sporočilo', 'duplicate': False, 'keep': True},
#   {'text': 'Ocena', 'duplicate': False, 'keep': True},
#   {'text': 'Komentiraj Za komentiranje ali ocenjevanje moraš biti registriran in prijavljen uporabnik. Registriraj se!',
#    'duplicate': True,
#    'keep': False}],
#  'primary_level_1': 'News/Reporting',
#  'primary_level_2': 'News/Reporting',
#  'primary_level_3': 'News/Reporting',
#  'secondary_level_1': '',
#  'secondary_level_2': '',
#  'secondary_level_3': '',
#  'tertiary_level_1': '',
#  'tertiary_level_2': '',
#  'tertiary_level_3': '',
#  'split': 'test',
#  'domain': 'www.pomurje.si',
#  'GINCORE': 'News'}

# %%
# Join all paragraphs with the attribute "keep" True into one text (attribute "full_text")

for instance in dataset:
    paragraphs = instance["paragraphs"]
    # Removing duplicates:
    paragraphs = [p for p in paragraphs if p["keep"]]

    # Joining texts:
    if len(paragraphs) > 0:
        instance_full_text = " <p/> ".join([p["text"] for p in paragraphs])

        # Assigning texts to a new field:
        instance["full_text"] = instance_full_text
    else:
        instance["full_text"] = ""

dataset[0]
# Out:
# {'id': '3949',
#  'url': 'http://www.pomurje.si/aktualno/sport/zimska-liga-malega-nogometa/',
#  'crawled': '2014',
#  'hard': False,
#  'paragraphs': [{'text': 'Šport', 'duplicate': False, 'keep': True},
#   {'text': 'Zimska liga malega nogometa sobota, 12.02.2011',
#    'duplicate': False,
#    'keep': True},
#   {'text': 'avtor: Tonček Gider', 'duplicate': False, 'keep': True},
#   {'text': "V 7. krogu zimske lige v malem nogometu v Križevcih pri Ljutomeru je v prvi ligi vodilni 100 plus iz Križevec izgubil s tretjo ekipo na lestvici Rock'n roll iz Križevec z rezultatom 1:2, druga na lestvici Top Finedika iz Križevec je bila poražena z ekipo Bar Milene iz Ključarovec z rezultatom 7:8. V drugi križevski ligi je vodilni Cafe del Mar iz Vučje vasi premagal Montažo Vrbnjak iz Stare Nove vasi z rezultatom 3:2.",
#    'duplicate': False,
#    'keep': True},
#   {'text': 'oglasno sporočilo', 'duplicate': False, 'keep': True},
#   {'text': 'Ocena', 'duplicate': False, 'keep': True},
#   {'text': 'Komentiraj Za komentiranje ali ocenjevanje moraš biti registriran in prijavljen uporabnik. Registriraj se!',
#    'duplicate': True,
#    'keep': False}],
#  'primary_level_1': 'News/Reporting',
#  'primary_level_2': 'News/Reporting',
#  'primary_level_3': 'News/Reporting',
#  'secondary_level_1': '',
#  'secondary_level_2': '',
#  'secondary_level_3': '',
#  'tertiary_level_1': '',
#  'tertiary_level_2': '',
#  'tertiary_level_3': '',
#  'split': 'test',
#  'domain': 'www.pomurje.si',
#  'GINCORE': 'News',
#  'full_text': "Šport <p/> Zimska liga malega nogometa sobota, 12.02.2011 <p/> avtor: Tonček Gider <p/> V 7. krogu zimske lige v malem nogometu v Križevcih pri Ljutomeru je v prvi ligi vodilni 100 plus iz Križevec izgubil s tretjo ekipo na lestvici Rock'n roll iz Križevec z rezultatom 1:2, druga na lestvici Top Finedika iz Križevec je bila poražena z ekipo Bar Milene iz Ključarovec z rezultatom 7:8. V drugi križevski ligi je vodilni Cafe del Mar iz Vučje vasi premagal Montažo Vrbnjak iz Stare Nove vasi z rezultatom 3:2. <p/> oglasno sporočilo <p/> Ocena"}

# %%
dataset[-1]
# Out:
# {'id': '1277644',
#  'url': 'https://pogajanja.si/?s=article&a=izpis&id=1221',
#  'crawled': '2021',
#  'hard': True,
#  'paragraphs': [{'text': 'Pogajalska akadmija v letu 2014 02.02.2014',
#    'duplicate': False,
#    'keep': True},
#   {'text': 'Kako se pogajati tako, da boste dosegli to, kar želite in ohranili dober odnos z drugo stranjo 3. RAZPIS USPEŠNE AKADEMIJE! Pridobite celovito pogajalsko znanje ter spretnosti, pridružite se nam na intenzivnem tečaju. Tečaj traja 21 šolskih ur in vključuje pet poldnevnih modulov v marcu in aprilu 2014: 6. marca, 13. marca, 20. marca, 27. marca in 3. aprila 2014 od 15.30 do 19.00. Srečanja bodo v prostorih podjetja Planet GV, seminarska dvorana, Poslovni center Alta, Železna cesta 18 v Ljubljani. VEČ>>',
#    'duplicate': False,
#    'keep': True}],
#  'primary_level_1': 'List of Summaries/Excerpts',
#  'primary_level_2': 'List of Summaries/Excerpts',
#  'primary_level_3': 'List of Summaries/Excerpts',
#  'secondary_level_1': '',
#  'secondary_level_2': '',
#  'secondary_level_3': '',
#  'tertiary_level_1': '',
#  'tertiary_level_2': '',
#  'tertiary_level_3': '',
#  'split': 'test',
#  'domain': 'pogajanja.si',
#  'GINCORE': 'List of Summaries/Excerpts',
#  'full_text': 'Pogajalska akadmija v letu 2014 02.02.2014 <p/> Kako se pogajati tako, da boste dosegli to, kar želite in ohranili dober odnos z drugo stranjo 3. RAZPIS USPEŠNE AKADEMIJE! Pridobite celovito pogajalsko znanje ter spretnosti, pridružite se nam na intenzivnem tečaju. Tečaj traja 21 šolskih ur in vključuje pet poldnevnih modulov v marcu in aprilu 2014: 6. marca, 13. marca, 20. marca, 27. marca in 3. aprila 2014 od 15.30 do 19.00. Srečanja bodo v prostorih podjetja Planet GV, seminarska dvorana, Poslovni center Alta, Železna cesta 18 v Ljubljani. VEČ>>'}

# %% [markdown]
# Save the dataset into a txt file which will be machine translated. Each text will be on a separate line, preceded by its id. Just one file is too large for DeepL which takes files up to 1 MB. Let's split it into three files.

# %%
new_file_part1 = open("GINCO-for-MT-part1-keeptext.txt","w")
new_file_part2 = open("GINCO-for-MT-part2-keeptext.txt","w")
new_file_part3 = open("GINCO-for-MT-part3-keeptext.txt","w")

counter = 0

for i in dataset:
    current_id = i["id"]
    current_text = i["full_text"]
    if counter <= 300:
        new_file_part1.write(f"{current_id}\t{current_text}\n")
    elif counter > 300 and counter <= 600:
        new_file_part2.write(f"{current_id}\t{current_text}\n")
    else:
        new_file_part3.write(f"{current_id}\t{current_text}\n")
    counter += 1


new_file_part1.close()
new_file_part2.close()
new_file_part3.close()

# %% [markdown]
# After translating the files with the DeepL system, let's join them and create a JSON file.

# %%
with open("GINCO-for-MT-part1-keeptext en-GB.txt", "r") as fileMT1:
    mt_text_part1 = fileMT1.readlines()
with open("GINCO-for-MT-part2-keeptext en-GB.txt", "r") as fileMT2:
    mt_text_part2 = fileMT2.readlines()
with open("GINCO-for-MT-part3-keeptext en-GB.txt", "r") as fileMT3:
    mt_text_part3 = fileMT3.readlines()

# %%
import parse

pattern = "{id} {text}\n"
pattern_id_only = "{id}\n"
compiled_pattern = parse.compile(pattern)
id_compiled_pattern = parse.compile(pattern_id_only)

MT_dataset = []

def parse_MT_file(file_name):
    """
    Function that takes the name of the txt file, created in previous steps and machine-translated,
    and parses it to obtain text ids and text.
    Args:
    file_name = the name of the file object, e.g. mt_text_part1
    """
    for line in file_name:
        if " " in line:
            result = compiled_pattern.parse(line)
            if result != None:
                current_id = result["id"]
                current_text = result["text"]
                current_dictionary = {"MT-id": current_id, "MT-text": current_text}
                MT_dataset.append(current_dictionary)
            else:
                print(line)
        else:
            empty_result = id_compiled_pattern.parse(line)
            if empty_result != None:
                current_id = empty_result["id"]
                current_text = ""
                current_dictionary = {"MT-id": current_id, "MT-text": current_text}
                MT_dataset.append(current_dictionary)
            else:
                print(line)

# %%
parse_MT_file(mt_text_part1)
parse_MT_file(mt_text_part2)
parse_MT_file(mt_text_part3)
print(len(MT_dataset))
# Out:
# 1002

# %%
print(MT_dataset[-3:])
# Out:
# [{'MT-id': '674213', 'MT-text': "About the product There are two women behind the Dame brand, and we've been more than impressed by the two products they've launched so far. Not because they're women, but because they obviously know [...] <p/> About the product The Satisfyer Partner Plus sex toy is a great way to show your partner how fantastic and fun erotic toys can be when they're included in your bedroom. A toy that will bring pleasure to both of you and [...] <p/> About product The Svakom Vick Vibrating Plug, a female G-spot and male P-spot massager, is an extremely versatile toy that not only looks nice, but is here to satisfy all your needs. This velvety soft seducer, made [...] <p/>About product It's time for the ultimate erotic toy in the form of a rabbit vibrator that is sure to become your muse for all your intimate play to come. In typical Satisfyer style, this toy also stimulates the clitoris without direct [...] <p/> About product The Lelo Bob is a smaller sized anal toy designed for all anal pleasure enthusiasts. Although its design is most recommended for gentlemen and their prostate, women are not excluded here. This beautiful anal plug, [...] <p/>About the product You will be amazed at the first sight of the Stronic G Vibrator. The shape, which is ideal for G-spot stimulation, the wonderful colour options and the very features of this vibrator will leave you completely enchanted. We can attribute its great success to [...] <p/> About the product Blush Novelties has introduced the world's first biodegradable ECO Gaia vibrator to the market, and now it's coming to our markets! It is made of a special bio plastic called BIOFEEL and consumes less [...] <p/> About the product Every now and then a product comes on the sex market that shakes the foundations of the sex industry with an innovative design or technology. This time, the Zumio clitoral stimulator has hit like a wave. Although at first glance the Zumio tip [...]"}, {'MT-id': '975590', 'MT-text': 'The debate often brings to the surface first those values that people in the kindergarten, school, organisation think they "should" have or "should value" in order to be respected as much as possible by themselves and the organisation. <p/> We know that the values people express publicly can be very different from the values they express in their own actions and behaviour. People\'s behaviour often seems to \'violate\' values that they claim to hold important and sacred. Such "double morality" is a commonplace phenomenon, reflecting the disconnect between one\'s actual values, what one really values and cares about, and how one would like others to see one. <p/> If this phenomenon is so typical of human beings, it is logical that it cannot be avoided when discussing values within an organisation. Such a discussion often brings to the surface, in particular, the values that people feel they "should" have or "should value" in order to make themselves and the organisation as attractive and respected as possible. <p/> If the values that are written down do not match those that the organisation and its people express in their actions and behaviour, they cannot have a positive impact on employees and users. <p/> Just as the "double morality" of the individual is unattractive, the "double morality" of the organisation, or the wide gap between its stated values and what its actions express, is an ideal breeding ground for cynicism, sarcasm, ridicule and other negative phenomena. Written values that are literally at odds with what happens in the organisation cannot possibly have a positive impact on its employees and users. On the contrary, they often become a source of further dissatisfaction. It is therefore all the more important that the debate on the values of the organisation really goes deep, not contenting itself with superficial answers, and that it examines and tests the values it evokes. <p/> For example, if the debate points out that what matters most to employ ...

# %% [markdown]
# Let's join the two datasets.

# %%
import pandas as pd

Sl_df = pd.DataFrame(dataset)
En_df = pd.DataFrame(MT_dataset)

En_df.columns = ["id","MT-text"]

# %%
Sl_df.head()
# Out:
#      id                                                url crawled   hard  \
# 0  3949  http://www.pomurje.si/aktualno/sport/zimska-li...    2014  False
# 1  3726  http://www.ss-sezana.si/sss/index.php?option=c...    2014  False
# 2  5621  http://www.kamnik-starejsi.si/novice/144-sodel...    2014  False
# 3  3776  http://www.radiocelje.si/novica.php?id=13007&a...    2014  False
# 4  2102  http://www.mtv.si/novice/selena-gomez-ponudila...    2014  False
#
#                                           paragraphs          primary_level_1  \
# 0  [{'text': 'Šport', 'duplicate': False, 'keep':...           News/Reporting
# 1  [{'text': 'JEDILNIK', 'duplicate': False, 'kee...  Information/Explanation
# 2  [{'text': 'Projekt INNOVAge in zavod Oreli', '...    Promotion of Services
# 3  [{'text': 'V novembru, mesecu preprečevanja od...           News/Reporting
# 4  [{'text': 'Selena Gomez ponudila v poslušanje ...         Opinionated News
#
#            primary_level_2          primary_level_3      secondary_level_1  \
# 0           News/Reporting           News/Reporting
# 1  Information/Explanation  Information/Explanation
# 2    Promotion of Services                Promotion  Opinion/Argumentation
# 3           News/Reporting           News/Reporting
# 4         Opinionated News         Opinionated News
#
#        secondary_level_2      secondary_level_3         tertiary_level_1  \
# 0
# 1
# 2  Opinion/Argumentation  Opinion/Argumentation  Information/Explanation
# 3
# 4
#
#           tertiary_level_2         tertiary_level_3  split  \
# 0                                                     test
# 1                                                    train
# 2  Information/Explanation  Information/Explanation  train
# 3                                                    train
# 4                                                     test
#
#                    domain                  GINCORE  \
# 0          www.pomurje.si                     News
# 1        www.ss-sezana.si  Information/Explanation
# 2  www.kamnik-starejsi.si                Promotion
# 3       www.radiocelje.si                     News
# 4              www.mtv.si                     News
#
#                                            full_text
# 0  Šport <p/> Zimska liga malega nogometa sobota,...
# 1  JEDILNIK <p/> Iskalnik <p/> Poglavitni cilj pr...
# 2  Projekt INNOVAge in zavod Oreli <p/> Zavod Ore...
# 3  V novembru, mesecu preprečevanja odvisnosti, b...
# 4  Selena Gomez ponudila v poslušanje novi album ...

# %%
En_df.head()
# Out:
#      id                                            MT-text
# 0  3949  Sport <p/> Winter Little League Football Satur...
# 1  3726  JEDILNIK <p/> Search <p/> The main objective o...
# 2  5621  Project INNOVAge and the Oreli Institute <p/> ...
# 3  3776  In November, the month of addiction prevention...
# 4  2102  Selena Gomez launches new album <p/> 16.07.201...

# %%
En_df.describe()
# Out:
#           id                                            MT-text
# count   1002                                               1002
# unique  1002                                               1002
# top     3949  Sport <p/> Winter Little League Football Satur...
# freq       1                                                  1

# %% [markdown]
# Let's check if all the ids are the same.

# %%
sl_ids = list(Sl_df.id.unique())
len(sl_ids)
# Out:
# 1002

# %%
en_ids = list(En_df.id.unique())
len(en_ids)
# Out:
# 1002

# %%
# Create a set of ids that are the same for both lists
same_ids = set(set(sl_ids) & set(en_ids))
len(same_ids)
# Out:
# 1002

# %%
# Find which element is not in the set
for element in sl_ids:
    if element not in same_ids:
        print(element)

# %% [markdown]
# At first, there was one id missing, I manually corrected the translation for this text so that the ids are the same.

# %%
# Join the datasets based on the IDs
joined_df = pd.merge(Sl_df, En_df, on=['id'])

# %%
joined_df.head()
# Out:
#      id                                                url crawled   hard  \
# 0  3949  http://www.pomurje.si/aktualno/sport/zimska-li...    2014  False
# 1  3726  http://www.ss-sezana.si/sss/index.php?option=c...    2014  False
# 2  5621  http://www.kamnik-starejsi.si/novice/144-sodel...    2014  False
# 3  3776  http://www.radiocelje.si/novica.php?id=13007&a...    2014  False
# 4  2102  http://www.mtv.si/novice/selena-gomez-ponudila...    2014  False
#
#                                           paragraphs          primary_level_1  \
# 0  [{'text': 'Šport', 'duplicate': False, 'keep':...           News/Reporting
# 1  [{'text': 'JEDILNIK', 'duplicate': False, 'kee...  Information/Explanation
# 2  [{'text': 'Projekt INNOVAge in zavod Oreli', '...    Promotion of Services
# 3  [{'text': 'V novembru, mesecu preprečevanja od...           News/Reporting
# 4  [{'text': 'Selena Gomez ponudila v poslušanje ...         Opinionated News
#
#            primary_level_2          primary_level_3      secondary_level_1  \
# 0           News/Reporting           News/Reporting
# 1  Information/Explanation  Information/Explanation
# 2    Promotion of Services                Promotion  Opinion/Argumentation
# 3           News/Reporting           News/Reporting
# 4         Opinionated News         Opinionated News
#
#        secondary_level_2      secondary_level_3         tertiary_level_1  \
# 0
# 1
# 2  Opinion/Argumentation  Opinion/Argumentation  Information/Explanation
# 3
# 4
#
#           tertiary_level_2         tertiary_level_3  split  \
# 0                                                     test
# 1                                                    train
# 2  Information/Explanation  Information/Explanation  train
# 3                                                    train
# 4                                                     test
#
#                    domain                  GINCORE  \
# 0          www.pomurje.si                     News
# 1        www.ss-sezana.si  Information/Explanation
# 2  www.kamnik-starejsi.si                Promotion
# 3       www.radiocelje.si                     News
# 4              www.mtv.si                     News
#
#                                            full_text  \
# 0  Šport <p/> Zimska liga malega nogometa sobota,...
# 1  JEDILNIK <p/> Iskalnik <p/> Poglavitni cilj pr...
# 2  Projekt INNOVAge in zavod Oreli <p/> Zavod Ore...
# 3  V novembru, mesecu preprečevanja odvisnosti, b...
# 4  Selena Gomez ponudila v poslušanje novi album ...
#
#                                              MT-text
# 0  Sport <p/> Winter Little League Football Satur...
# 1  JEDILNIK <p/> Search <p/> The main objective o...
# 2  Project INNOVAge and the Oreli Institute <p/> ...
# 3  In November, the month of addiction prevention...
# 4  Selena Gomez launches new album <p/> 16.07.201...

# %%
print(list(joined_df.columns))
# Out:
# ['id', 'url', 'crawled', 'hard', 'paragraphs', 'primary_level_1', 'primary_level_2', 'primary_level_3', 'secondary_level_1', 'secondary_level_2', 'secondary_level_3', 'tertiary_level_1', 'tertiary_level_2', 'tertiary_level_3', 'split', 'domain', 'GINCORE', 'full_text', 'MT-text']

# %%
final_dataset = joined_df[['id', 'url', 'crawled', 'hard', 'primary_level_1', 'primary_level_2', 'primary_level_3', 'secondary_level_1', 'secondary_level_2', 'secondary_level_3', 'tertiary_level_1', 'tertiary_level_2', 'tertiary_level_3', 'split', 'domain', 'GINCORE', 'full_text', 'MT-text']]

# %%
final_dataset.tail()
# Out:
#            id                                                url crawled  \
# 997    374730  http://khetanes.si/sl-si/produkti/projektne-no...    2021
# 998    476885  https://www.merkur.si/navigacija/nasveti/kopal...    2021
# 999    674213        http://www.sex2.si/category/ocene-izdelkov/    2021
# 1000   975590  http://www.ipsos.si/VodenjeVIZ_VI_past_dvojne_...    2021
# 1001  1277644    https://pogajanja.si/?s=article&a=izpis&id=1221    2021
#
#        hard             primary_level_1             primary_level_2  \
# 997   False     Information/Explanation     Information/Explanation
# 998   False  List of Summaries/Excerpts  List of Summaries/Excerpts
# 999   False  List of Summaries/Excerpts  List of Summaries/Excerpts
# 1000  False       Opinion/Argumentation       Opinion/Argumentation
# 1001   True  List of Summaries/Excerpts  List of Summaries/Excerpts
#
#                  primary_level_3 secondary_level_1 secondary_level_2  \
# 997      Information/Explanation
# 998   List of Summaries/Excerpts
# 999   List of Summaries/Excerpts
# 1000       Opinion/Argumentation
# 1001  List of Summaries/Excerpts
#
#      secondary_level_3        tertiary_level_1        tertiary_level_2  \
# 997                     Promotion of a Product  Promotion of a Product
# 998
# 999
# 1000
# 1001
#
#      tertiary_level_3  split         domain                     GINCORE  \
# 997         Promotion  train    khetanes.si     Information/Explanation
# 998                    train  www.merkur.si  List of Summaries/Excerpts
# 999                    train    www.sex2.si  List of Summaries/Excerpts
# 1000                   train   www.ipsos.si       Opinion/Argumentation
# 1001                    test   pogajanja.si  List of Summaries/Excerpts
#
#                                               full_text  \
# 997   Projektne novine <p/> Promocijski projektni ča...
# 998   V raznoliki ponudbi tušev izberite popolno raz...
# 999   O izdelku Za znamko Dame stojita dve ženski, z...
# 1000  Razprava pogosto potegne na plano najprej tist...
# 1001  Pogajalska akadmija v letu 2014 02.02.2014 <p/...
#
#                                                 MT-text
# 997   Project News <p/> Promotional project newspape...
# 998   Choose the perfect shower to match your taste ...
# 999   About the product There are two women behind t...
# 1000  The debate often brings to the surface first t...
# 1001  Negotiation Academy 2014 02.02.2014 <p/> How t...

# %%
final_dataset.describe()
# Out:
#           id                                     url crawled   hard  \
# count   1002                                    1002    1002   1002
# unique  1002                                     881       2      2
# top     3949  https://publishwall.si/pozareport.7dni    2014  False
# freq       1                                      10     501    933
#
#                 primary_level_1          primary_level_2 primary_level_3  \
# count                      1002                     1002            1002
# unique                       24                       21              12
# top     Information/Explanation  Information/Explanation       Promotion
# freq                        130                      130             209
#
#        secondary_level_1 secondary_level_2 secondary_level_3 tertiary_level_1  \
# count               1002              1002              1002             1002
# unique                14                14                10               14
# top
# freq                 812               812               812              849
#
#        tertiary_level_2 tertiary_level_3  split          domain    GINCORE  \
# count              1002             1002   1002            1002       1002
# unique               14                9      3             721         20
# top                                       train  publishwall.si  Promotion
# freq                849              849    602              10        209
#
#                                                 full_text  \
# count                                                1002
# unique                                               1002
# top     Šport <p/> Zimska liga malega nogometa sobota,...
# freq                                                    1
#
#                                                   MT-text
# count                                                1002
# unique                                               1002
# top     Sport <p/> Winter Little League Football Satur...
# freq                                                    1

# %% [markdown]
# As we did not use all the text (but only the text with the parameter "keep"), let's check if there are any empty or very short texts.

# %%
final_dataset["text_length"] = final_dataset["full_text"].str.split().str.len()

final_dataset
# Out:
#            id                                                url crawled  \
# 0        3949  http://www.pomurje.si/aktualno/sport/zimska-li...    2014
# 1        3726  http://www.ss-sezana.si/sss/index.php?option=c...    2014
# 2        5621  http://www.kamnik-starejsi.si/novice/144-sodel...    2014
# 3        3776  http://www.radiocelje.si/novica.php?id=13007&a...    2014
# 4        2102  http://www.mtv.si/novice/selena-gomez-ponudila...    2014
# ...       ...                                                ...     ...
# 997    374730  http://khetanes.si/sl-si/produkti/projektne-no...    2021
# 998    476885  https://www.merkur.si/navigacija/nasveti/kopal...    2021
# 999    674213        http://www.sex2.si/category/ocene-izdelkov/    2021
# 1000   975590  http://www.ipsos.si/VodenjeVIZ_VI_past_dvojne_...    2021
# 1001  1277644    https://pogajanja.si/?s=article&a=izpis&id=1221    2021
#
#        hard             primary_level_1             primary_level_2  \
# 0     False              News/Reporting              News/Reporting
# 1     False     Information/Explanation     Information/Explanation
# 2     False       Promotion of Services       Promotion of Services
# 3     False              News/Reporting              News/Reporting
# 4     False            Opinionated News            Opinionated News
# ...     ...                         ...                         ...
# 997   False     Information/Explanation     Information/Explanation
# 998   False  List of Summaries/Excerpts  List of Summaries/Excerpts
# 999   False  List of Summaries/Excerpts  List of Summaries/Excerpts
# 1000  False       Opinion/Argumentation       Opinion/Argumentation
# 1001   True  List of Summaries/Excerpts  List of Summaries/Excerpts
#
#                  primary_level_3      secondary_level_1  \
# 0                 News/Reporting
# 1        Information/Explanation
# 2                      Promotion  Opinion/Argumentation
# 3                 News/Reporting
# 4               Opinionated News
# ...                          ...                    ...
# 997      Information/Explanation
# 998   List of Summaries/Excerpts
# 999   List of Summaries/Excerpts
# 1000       Opinion/Argumentation
# 1001  List of Summaries/Excerpts
#
#           secondary_level_2      secondary_level_3         tertiary_level_1  \
# 0
# 1
# 2     Opinion/Argumentation  Opinion/Argumentation  Information/Explanation
# 3
# 4
# ...                     ...                    ...                      ...
# 997                                                  Promotion of a Product
# 998
# 999
# 1000
# 1001
#
#              tertiary_level_2         tertiary_level_3  split  \
# 0                                                        test
# 1                                                       train
# 2     Information/Explanation  Information/Explanation  train
# 3                                                       train
# 4                                                        test
# ...                       ...                      ...    ...
# 997    Promotion of a Product                Promotion  train
# 998                                                     train
# 999                                                     train
# 1000                                                    train
# 1001                                                     test
#
#                       domain                     GINCORE  \
# 0             www.pomurje.si                        News
# 1           www.ss-sezana.si     Information/Explanation
# 2     www.kamnik-starejsi.si                   Promotion
# 3          www.radiocelje.si                        News
# 4                 www.mtv.si                        News
# ...                      ...                         ...
# 997              khetanes.si     Information/Explanation
# 998            www.merkur.si  List of Summaries/Excerpts
# 999              www.sex2.si  List of Summaries/Excerpts
# 1000            www.ipsos.si       Opinion/Argumentation
# 1001            pogajanja.si  List of Summaries/Excerpts
#
#                                               full_text  \
# 0     Šport <p/> Zimska liga malega nogometa sobota,...
# 1     JEDILNIK <p/> Iskalnik <p/> Poglavitni cilj pr...
# 2     Projekt INNOVAge in zavod Oreli <p/> Zavod Ore...
# 3     V novembru, mesecu preprečevanja odvisnosti, b...
# 4     Selena Gomez ponudila v poslušanje novi album ...
# ...                                                 ...
# 997   Projektne novine <p/> Promocijski projektni ča...
# 998   V raznoliki ponudbi tušev izberite popolno raz...
# 999   O izdelku Za znamko Dame stojita dve ženski, z...
# 1000  Razprava pogosto potegne na plano najprej tist...
# 1001  Pogajalska akadmija v letu 2014 02.02.2014 <p/...
#
#                                                 MT-text  text_length
# 0     Sport <p/> Winter Little League Football Satur...           93
# 1     JEDILNIK <p/> Search <p/> The main objective o...           76
# 2     Project INNOVAge and the Oreli Institute <p/> ...          232
# 3     In November, the month of addiction prevention...          158
# 4     Selena Gomez launches new album <p/> 16.07.201...           63
# ...                                                 ...          ...
# 997   Project News <p/> Promotional project newspape...           86
# 998   Choose the perfect shower to match your taste ...           50
# 999   About the product There are two women behind t...          295
# 1000  The debate often brings to the surface first t...          409
# 1001  Negotiation Academy 2014 02.02.2014 <p/> How t...           89
#
# [1002 rows x 19 columns]

# %%
nonduplicated_dataset = final_dataset[final_dataset["text_length"] < 11]

nonduplicated_dataset.head()
# Out:
# Empty DataFrame
# Columns: [id, url, crawled, hard, primary_level_1, primary_level_2, primary_level_3, secondary_level_1, secondary_level_2, secondary_level_3, tertiary_level_1, tertiary_level_2, tertiary_level_3, split, domain, GINCORE, full_text, MT-text, text_length]
# Index: []

# %% [markdown]
# There is none such text.

# %% [markdown]
# Save the file with Slovene and English text:

# %%
new_GINCO_file = final_dataset.to_json("Sl-and-MT-GINCO-mapped-to-GINCORE-keeptext.json", orient="index",indent=2)
csv_file = final_dataset.to_csv("Sl-and-MT-GINCO-mapped-to-GINCORE-keeptext.csv",index=False)
